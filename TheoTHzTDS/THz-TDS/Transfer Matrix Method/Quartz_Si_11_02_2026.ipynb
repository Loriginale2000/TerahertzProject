# %%
import sys 
import os

import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# MOVE UP ONE DIRECTORY FROM THE NOTEBOOK LOCATION
notebook_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

# ADD THAT DIRECTORY TO SYS.PATH IF NOT ALREADY PRESENT
if notebook_root not in sys.path:
    sys.path.insert(0, notebook_root)
    
from Matrix_methods.Simulate import simulate_parallel
from Matrix_methods.BayesianExtractor import BayesianLayeredExtractor
from Matrix_methods.AdamExtractor import LayeredExtractor

# %%
# INSERT REFERENCE DATA 
reference_pulse = np.loadtxt(r"C:\miniconda_projects\repository\TerahertzProject\TheoTHzTDS\THz-TDS\Transfer Matrix Method\data_11_02_2026\Reference_15min_nitrogen (1).txt",dtype=float)

# INSERT SAMPLE DATA
sample_pulse_Quartz_HRZ_Si = np.loadtxt(r"C:\miniconda_projects\repository\TerahertzProject\TheoTHzTDS\THz-TDS\Transfer Matrix Method\data_11_02_2026\Quartz_Si_15min_nitrogen.txt",dtype=float)

t1= reference_pulse[:,0] + 740  # ADJUSTING THE AXIS
amp1 = reference_pulse[:,1]
t2 = sample_pulse_Quartz_HRZ_Si[:,0] + 740  # ADJUSTING THE AXIS
amp2 = sample_pulse_Quartz_HRZ_Si[:,1]
time_axis_ref = t1
ref_pulse = amp1
time_axis_sample = t2
sample_pulse = amp2

# SAMPLE_PULSE -= BIAS


L = len(ref_pulse)
print(f'Time domain sampling: {L}')


plt.figure(figsize=(12,4))
plt.scatter(time_axis_ref, ref_pulse, label='ref pulse', s=1)
plt.scatter(time_axis_sample, sample_pulse, label='Quartz-HRZ_Si', s=1)
plt.xlabel('Time, t [ps]')
plt.legend()
plt.show()
# Out:
# Time domain sampling: 2425

# %%
def compare_material_stacks(calculated, real):
    """
    Compare two material parameter stacks with separate real/imag errors for n.
    
    Args:
        calculated (list of tuples): [(n_complex, thickness_m), ...]
        real (list of tuples): [(n_complex, thickness_m), ...]
    
    Returns:
        list of dicts with abs and % errors for n_real, n_imag, and thickness.
    """
    results = []
    for i, ((n_calc, d_calc), (n_true, d_true)) in enumerate(zip(calculated, real), start=1):
        
        # Refractive index real part errors
        n_real_abs_err = abs(n_calc.real - n_true.real)
        n_real_pct_err = (n_real_abs_err / abs(n_true.real)) * 100 if n_true.real != 0 else float('inf')
        
        # Refractive index imaginary part errors
        n_imag_abs_err = abs(n_calc.imag - n_true.imag)
        n_imag_pct_err = (n_imag_abs_err / abs(n_true.imag)) * 100 if n_true.imag != 0 else float('inf')

        # Thickness errors
        d_abs_err = abs(d_calc - d_true)
        d_pct_err = (d_abs_err / abs(d_true)) * 100 if d_true != 0 else float('inf')

        results.append({
            "layer": i,
            "n_real_abs_err": n_real_abs_err,
            "n_real_pct_err": n_real_pct_err,
            "n_imag_abs_err": n_imag_abs_err,
            "n_imag_pct_err": n_imag_pct_err,
            "d_abs_err": d_abs_err,
            "d_pct_err": d_pct_err
        })
    
    return results

# %%
## CHECK TIME STEPS ARE CONSISTENT IN T_AXIS
# COMPUTE TIME DIFFERENCES BETWEEN CONSECUTIVE SAMPLES
dt = np.diff(time_axis_ref)

# CHECK FOR UNIFORM TIME STEP (WITHIN A SMALL TOLERANCE)
tolerance = 0.5e-12  # ADJUST AS NEEDED BASED ON YOUR SIGNAL'S PRECISION
is_uniform = np.all(np.abs(dt - dt[0]) < tolerance)

print("Time steps are uniform:", is_uniform)
if is_uniform:
    deltat = dt[0]
    print(f'delta_t: {deltat} ps')
if not is_uniform:
    print("Min dt:", np.min(dt))
    print("Max dt:", np.max(dt))
    print("Mean dt:", np.mean(dt))

deltat = np.mean(dt)
deltat = deltat * 1e-12  # CONVERT TO SECONDS FOR CALCULATIONS
# Out:
# Time steps are uniform: False
# Min dt: 0.03300329999990481
# Max dt: 0.033003309999912744
# Mean dt: 0.033003300330033

# %%
# EXTRACTION: INITIAL GUESS AND OPTIMIZATION SETTINGS

n_Qa = 1.9820
k_Qa= -0.0071  
d_Qa = 1000e-6
n_HRZ_Si= 3.2990
k_HRZ_Si = -0.0054
d_HRZ_Si = 400e-6


optimize_mask = [
    (True, True,True),  # QA
    (True, True, True)  # HRZ_SI
]

init_guess = [
   
    ((n_Qa + 1j*k_Qa), d_Qa),  # QA
    ((n_HRZ_Si + 1j*k_HRZ_Si), d_HRZ_Si),  # HRZ_SI
    
]

optimization_bounds = [0.4,0.001,50e-06]

# CONVERT REF TO TORCH TENSOR 
ref_pulse_t = torch.tensor(ref_pulse, dtype=torch.float32) 
sample_pulse_t = torch.tensor(sample_pulse, dtype=torch.float32) 

init_pulse = simulate_parallel(ref_pulse_t, init_guess, deltat, noise_level=0)[1].detach().cpu().numpy()[:L]

Bayes_model = BayesianLayeredExtractor(ref_pulse_t, sample_pulse_t, deltat=deltat, layers_init=init_guess,  optimization_bounds=optimization_bounds,optimize_mask=optimize_mask)
bayes_params = Bayes_model.bayesian_optimization(n_calls=50)

Bayesian_pulse = simulate_parallel(ref_pulse_t, bayes_params, deltat, noise_level=0)[1].detach().cpu().numpy()[:L]


# FINDING INDIVIDUAL VALUES
n_complex_bays1, D_bays1 = bayes_params[0]
n_bays1 = abs(n_complex_bays1.real)
k_bays1 = abs(n_complex_bays1.imag)
n_complex_bays2, D_bays2 = bayes_params[1]
n_bays2 = abs(n_complex_bays2.real) 
k_bays2 = abs(n_complex_bays2.imag)

print(f'Bayes params: {bayes_params}')
plt.figure(figsize=(12,4))
plt.plot(time_axis_ref, ref_pulse_t, label='ref pulse', alpha=0.5)
plt.plot(time_axis_sample, sample_pulse_t, label='exp pulse')
plt.plot(time_axis_sample, init_pulse, label='init pulse', alpha = 0.5)
plt.plot(time_axis_sample, Bayesian_pulse, label='bayes pulse')
plt.xlabel('Time, t [ps]')
plt.legend()
plt.show()
# Out:
# Starting Bayesian Optimization with masks...
# Search Boundaries for Optimized Parameters:
# Layer 1 - n ∈ (1.5819999999999999, 2.382)
# Layer 1 - k ∈ (-0.0081, -0.0061)
# Layer 1 - D ∈ (0.00095, 0.00105)
# Layer 2 - n ∈ (2.899, 3.699)
# Layer 2 - k ∈ (-0.0064, -0.0044)
# Layer 2 - D ∈ (0.00035, 0.00045000000000000004)
# Bayes params: [((1.9372838299911177-0.0071707951551353896j), 0.001015379306338621), ((3.3216935323034713-0.004693197607144831j), 0.00040016659110898395)]

# %%
grad_optimizer = LayeredExtractor(ref_pulse_t, sample_pulse_t, deltat, bayes_params, optimize_mask, lr=0.001)
optim_params = grad_optimizer.optimize(num_iterations=1000, updates=200, alpha=1)



optim_pulse = simulate_parallel(ref_pulse_t, optim_params, deltat, 0)[1].detach().cpu().numpy()[:L]

n_complex_adam1, D_adam1 = optim_params[0]
n_adam1 = abs(n_complex_adam1.real)
k_adam1 = abs(n_complex_adam1.imag)
n_complex_adam2, D_adam2 = optim_params[1]
n_adam2 = abs(n_complex_adam2.real)
k_adam2 = abs(n_complex_adam2.imag)

print(optim_params)
plt.figure(figsize=(12,4))
plt.plot(time_axis_ref, ref_pulse_t, label='ref pulse', alpha=0.7,linewidth=1.5)
plt.plot(time_axis_sample, sample_pulse_t, label='exp pulse',alpha=0.7,linewidth=1.5)
plt.plot(time_axis_sample, Bayesian_pulse, label='bayes pulse', alpha = 0.7,linewidth=2)
plt.plot(time_axis_sample, optim_pulse, label='optim pulse',linestyle='--' ,color='black',linewidth=1.5)
plt.xlabel('Time, t [ps]')
plt.legend()
plt.show()
# Out:
# Fine-tuning 6 parameters for 1000 iterations.
# Iteration 199, Loss: 1.128350e-02, Layer 0: n=1.9863, k=-0.00664, D=982.94 µm | Layer 1: n=3.3476, k=0.00520, D=392.89 µm
# Iteration 399, Loss: 1.127571e-02, Layer 0: n=1.9872, k=-0.00675, D=982.46 µm | Layer 1: n=3.3435, k=0.00539, D=393.38 µm
# Iteration 599, Loss: 1.126726e-02, Layer 0: n=1.9884, k=-0.00687, D=981.87 µm | Layer 1: n=3.3384, k=0.00562, D=393.97 µm
# Iteration 799, Loss: 1.125942e-02, Layer 0: n=1.9897, k=-0.00701, D=981.23 µm | Layer 1: n=3.3331, k=0.00587, D=394.61 µm
# Iteration 999, Loss: 1.125299e-02, Layer 0: n=1.9910, k=-0.00714, D=980.59 µm | Layer 1: n=3.3278, k=0.00612, D=395.24 µm
# [((1.990959644317627-0.007143730763345957j), 0.000980593147687614), ((3.327755928039551+0.006122158374637365j), 0.0003952419792767614)]

# %%
optim_params
# Out:
# [((1.990959644317627-0.007143730763345957j), 0.000980593147687614),
#  ((3.327755928039551+0.006122158374637365j), 0.0003952419792767614)]

# %%
final_loss_value = grad_optimizer.loss_history[-1]
min_loss_value = min(grad_optimizer.loss_history)

# COMPARISON BETWEEN THOSE TWO

pc_loss = abs(final_loss_value - min_loss_value) / abs(min_loss_value) * 100
print(f"Percentage Change in Loss: {pc_loss:.6f}%")
# Out:
# Percentage Change in Loss: 0.000000%

# %%
# MAKING A DATAFRAME TO STORE RESULTS IN EACH INDIVIDUAL EXTRACTION

# NAMES 
param_names_A = ["n_Quartz", "k_Quartz", "d_Quartz"]  

# STORING INITIAL GUESS VALUES
initial_Quartz = np.array([n_Qa, k_Qa, d_Qa])

# EXTRACTED VALUES
final_Quartz   = np.array([optim_params[0][0].real, optim_params[0][0].imag, optim_params[0][1]])

# BUILDING THE DATAFRAME
comparison_Quartz = pd.DataFrame({
    'Parameter': param_names_A,
    'Initial Guess Value': initial_Quartz.round(5),
    'Extracted Value'  : final_Quartz.round(5),
    'Minimum Loss Achieved': min(grad_optimizer.loss_history)
    
})

# MAKING A DATAFRAME TO STORE RESULTS IN EACH INDIVIDUAL EXTRACTION

# NAMES 
param_names_B = ["n_HRZ_Si", "k_HRZ_Si", "d_HRZ_Si"]  

# STORING INITIAL GUESS VALUES
initial_Si = np.array([n_HRZ_Si, k_HRZ_Si, d_HRZ_Si])

# EXTRACTED VALUES
final_Si   = np.array([optim_params[1][0].real, optim_params[1][0].imag, optim_params[1][1]])

# BUILDING THE DATAFRAME
comparison_Si = pd.DataFrame({
    'Parameter': param_names_B,
    'Initial Guess Value': initial_Si.round(5),
    'Extracted Value'  : final_Si.round(5),
    "Minimum Loss Achieved": min(grad_optimizer.loss_history)
    
})

print("Quartz Comparison:")
print(comparison_Quartz)
print("\nSilicon Comparison:")
print(comparison_Si)
# Out:
# Quartz Comparison:
#   Parameter  Initial Guess Value  Extracted Value  Minimum Loss Achieved
# 0  n_Quartz               1.9820          1.99096               0.011253
# 1  k_Quartz              -0.0071         -0.00714               0.011253
# 2  d_Quartz               0.0010          0.00098               0.011253
#
# Silicon Comparison:
#   Parameter  Initial Guess Value  Extracted Value  Minimum Loss Achieved
# 0  n_HRZ_Si               3.2990          3.32776               0.011253
# 1  k_HRZ_Si              -0.0054          0.00612               0.011253
# 2  d_HRZ_Si               0.0004          0.00040               0.011253

# %%
# PERCENTAGE DIFFS, EXPERIMENTAL DATA VERSUS NR METHOD EXTRACTED VALUES

# FOR QUARTZ VALUES 
n_diff = abs((optim_params[0][0].real - 1.9621) / optim_params[0][0].real * 100)
k_diff =abs( (optim_params[0][0].imag - (-0.0071)) / optim_params[0][0].imag * 100)
d_diff =abs( (optim_params[0][1] - 999.948e-6) / optim_params[0][1] * 100)

# FOR HRZ_SI VALUES
n_diff_Si = abs((optim_params[1][0].real - 3.4094) / optim_params[1][0].real * 100)
k_diff_Si =abs( (-optim_params[1][0].imag - (-0.0053)) / optim_params[1][0].imag * 100)
d_diff_Si =abs( (optim_params[1][1] - 400.066e-6) / optim_params[1][1] * 100)


# PRINT RESULTS

print(f"Quartz: n_diff = {n_diff:.2f}%, k_diff = {k_diff:.2f}%, d_diff = {d_diff:.2f}%")
print(f"HRZ_Si: n_diff = {n_diff_Si:.2f}%, k_diff = {k_diff_Si:.2f}%, d_diff = {d_diff_Si:.2f}%")
# Out:
# Quartz: n_diff = 1.45%, k_diff = 0.61%, d_diff = 1.97%
# HRZ_Si: n_diff = 2.45%, k_diff = 13.43%, d_diff = 1.22%

# %%
plt.semilogy(grad_optimizer.loss_history, label='Loss')
plt.xlabel("Iterations")
plt.ylabel("rMSE")
plt.grid(True, which="both", ls="--", linewidth=0.5)
#plt.xlim(100, 2000)
plt.title("Loss History During Adam, Experimental Extraction")
plt.legend()
plt.show()

# %%
'''
# LOSS LANDSCAPE
from loss_landscape_visualization_multiple_layer import visualize_multilayer_landscape


param_ranges_per_layer = [
        # QUARTZ 
        {
            'n': (1.4, 2.5),    
            'k': (0.002, 0.0082),
            'd': (0.5e-3, 1.5e-3) 
        },
        # HRZ_SI
        {
            'n': (2.81, 3.810),
            'k': (0.0024, 0.0084),
            'd': (0.2e-3, 0.6e-3)   
        }
    ]


    # RUN MULTI-LAYER LANDSCAPE ANALYSIS
analyses = visualize_multilayer_landscape(
    x_exp=ref_pulse_t,
    true_x_exp=sample_pulse_t, 
    deltat=deltat,
    L=L,
    bayesian_layers = bayes_params,
    adam_layers=optim_params,
    param_ranges_per_layer=param_ranges_per_layer,
    bayesian_history=Bayes_model.iteration_history,  
    adam_history=grad_optimizer.iteration_history,
    resolution=40)  
'''
# Out:
# "\n# LOSS LANDSCAPE\nfrom loss_landscape_visualization_multiple_layer import visualize_multilayer_landscape\n\n\nparam_ranges_per_layer = [\n        # QUARTZ \n        {\n            'n': (1.4, 2.5),    \n            'k': (0.002, 0.0082),\n            'd': (0.5e-3, 1.5e-3) \n        },\n        # HRZ_SI\n        {\n            'n': (2.81, 3.810),\n            'k': (0.0024, 0.0084),\n            'd': (0.2e-3, 0.6e-3)   \n        }\n    ]\n\n\n    # RUN MULTI-LAYER LANDSCAPE ANALYSIS\nanalyses = visualize_multilayer_landscape(\n    x_exp=ref_pulse_t,\n    true_x_exp=sample_pulse_t, \n    deltat=deltat,\n    L=L,\n    bayesian_layers = bayes_params,\n    adam_layers=optim_params,\n    param_ranges_per_layer=param_ranges_per_layer,\n    bayesian_history=Bayes_model.iteration_history,  \n    adam_history=grad_optimizer.iteration_history,\n    resolution=40)  \n"

# %%
from Matrix_methods.Loss_Grid_Visualization import generate_landscape_multi_layer 

# INITIAL GUESS FOR BOTH LAYERS
layers_init = [
    (1.9820 - 0.0071j, 1000e-6), # LAYER 0 : QUARTZ SLIDE
    (3.2990 - 0.0054j, 400e-6)   # LAYER 1: HRZ_SI SLIDE
]

# HERE, WE DEFINE THE RANGES FOR THE SWEEP OF EACH PARAMETER VALUE 
sweep_ranges = {
    # LAYER 0
    (0, 'n'): (1.6, 2.6),
    (0, 'k'): (-0.008, 0.008),
    (0, 'd'): (900e-6, 1120e-6),

}

# SIMULATE LANDSCAPE
landscape_results =generate_landscape_multi_layer(
    ref_pulse_t, sample_pulse_t, deltat, layers_init=layers_init, param_ranges=sweep_ranges, num_samples=10000)

# %%
from Matrix_methods.Loss_Grid_Visualization import plot_results_multi_layer

# PLOTTING THE RESULTS 

plots_multi_Quartz = plot_results_multi_layer(landscape_results, layer_idx=0)

# %%
# Sweep Silicon (Layer 1), leave Quartz (Layer 0) alone
sweep_ranges_isolated_si = {
    
    (1, 'n'): (2.5, 4),
    (1, 'k'): (-0.008, 0.008),
    (1, 'd'): (350e-6, 450e-6)
}

# ISOLATED SI RANGE
si_landscape = generate_landscape_multi_layer(
    ref_pulse_t, sample_pulse_t, deltat, layers_init, sweep_ranges_isolated_si, num_samples=10000
)

plot_results_multi_layer(si_landscape, layer_idx=1)

# %%
def get_bayes_history(optimizer_results):
    """
    Converts bayesian results to the same format as we need [tuple]
    """
    bayes_history = []
    
    # Sort by time/iteration to ensure the path line is drawn in order
    # Most Bayes optimizers store results in .res or .trials
    for res in optimizer_results:
        # res['params'] usually looks like {'n0': 1.95, 'd0': 0.0004}
        # We clone it and add it to our history list
        step = res['params'].copy()
        bayes_history.append(step)
        
    return bayes_history

# %%
from Matrix_methods.Loss_Structured_Grid_Visualization import generate_landscape_grid,plot_grid_landscape
adam_history = grad_optimizer.iteration_history
bayes_history = Bayes_model.iteration_history

n_d_Q = { (0, 'n'): (1.8, 2.2), (0, 'd'): (900e-6, 1100e-6) }
data, a1, a2, keys = generate_landscape_grid(ref_pulse_t, sample_pulse_t, deltat, init_guess , n_d_Q, num_points=100)
plot_grid_landscape(data, a1, a2,keys)

# %%
adam_history[0].keys()
keys
# Out:
# [(0, 'n'), (0, 'd')]

# %%
n_k_Q = {(0,'n'):(1.8,2.2),(0,'k'):(-0.008,0.008)}
data, a1, a2, keys = generate_landscape_grid(ref_pulse_t, sample_pulse_t, deltat, init_guess, n_k_Q, num_points=100)
plot_grid_landscape(data, a1, a2, keys)

# %%
n_d_Si = {(1,'n'):(3,4),(1,'d'):(360e-6,460e-6)}
data, a1, a2, keys = generate_landscape_grid(ref_pulse_t, sample_pulse_t, deltat, init_guess, n_d_Si, num_points=100)
plot_grid_landscape(data, a1, a2, keys)

# %%
n_k_Si = {(1,'n'):(2.9,3.6),(1,'k'):(-0.006,0.006)}
data, a1, a2, keys = generate_landscape_grid(ref_pulse_t, sample_pulse_t, deltat, init_guess, n_k_Si, num_points=100)
plot_grid_landscape(data, a1, a2, keys)

# %%
adam_history = grad_optimizer.iteration_history
bayes_history = Bayes_model.iteration_history
